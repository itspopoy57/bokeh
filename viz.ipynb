# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

from bokeh.io import output_file, show
import pandas

points = pandas.read_csv('lotlat.csv')

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

x = points['latitude'].values
y = points['longitude'].values
z = points['altitude (m)'].values

#  x   y   z  
# 1.1,1.2,1.3
# 2.1,2.2,2.3
# 3.1,3.2,3.3
# 4.1,4.2,4.3

#ax.plot_wireframe(x, y, z, c='r', marker='o')
ax.scatter(x, y, z, c='r', marker='|')
#ax.scatter(x, y, z=0, zdir='z', s=20, c=None, depthshade=True, marker='.')


plt.show()
plt.savefig("wow.jpg")
